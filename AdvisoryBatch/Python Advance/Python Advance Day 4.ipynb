# %% [markdown]
# ## Python Advance Day 4

# %% [markdown]
# #### pandas continued...

# %%
# Working with different types of files using Pandas

# %%
# CSV Files
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/pvashishtha/DelDWH/main/covid19.csv')
df
# Out:
#      Country/Region               Province/State  Confirmed  Recovered  \
# 0             India  Andaman and Nicobar Islands         33         33
# 1             India               Andhra Pradesh       5070       2802
# 2             India            Arunachal Pradesh         57          1
# 3             India                        Assam       2937       1085
# 4             India                        Bihar       5459       2864
# ...             ...                          ...        ...        ...
# 5756          India                      Tripura      31919      30414
# 5757          India                      Unknown          0          0
# 5758          India                Uttar Pradesh     507602     477180
# 5759          India                  Uttarakhand      67706      62302
# 5760          India                  West Bengal     424675     385617
#
#       Deaths        Date
# 0          0   6/10/2020
# 1         77   6/10/2020
# 2          0   6/10/2020
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5761 entries, 0 to 5760
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country/Region  5761 non-null   object
#  1   Province/State  5761 non-null   object
#  2   Confirmed       5761 non-null   int64
#  3   Recovered       5761 non-null   int64
#  4   Deaths          5761 non-null   int64
#  5   Date            5761 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 270.2+ KB

# %%
df.describe()
# Out:
#           Confirmed     Recovered        Deaths
# count  5.761000e+03  5.761000e+03   5761.000000
# mean   1.067698e+05  8.853623e+04   1780.701961
# std    2.168770e+05  1.873636e+05   4900.147192
# min    0.000000e+00  0.000000e+00      0.000000
# 25%    3.140000e+03  2.152000e+03     14.000000
# 50%    1.852200e+04  1.318600e+04    245.000000
# 75%    1.203360e+05  9.323600e+04   1293.000000
# max    1.740461e+06  1.609607e+06  45809.000000

# %%
df.isna().sum()
# Out:
# Country/Region    0
# Province/State    0
# Confirmed         0
# Recovered         0
# Deaths            0
# Date              0
# dtype: int64

# %%
# Excel Files

# %%
df=pd.read_excel('data.xlsx')
df
# Out:
#                Deloitte Email ID                       Full Name  \
# 0       AARCAGRAWAL@DELOITTE.COM                  Aarchi Agrawal
# 1          AKKAKANI@DELOITTE.COM                   Akshit Kakani
# 2       ANASONAWANE@DELOITTE.COM                 Anagha Sonawane
# 3         CHITIWARI@DELOITTE.COM              Chiranjeev  Tiwari
# 4            DMONCY@DELOITTE.COM                      Dawn Moncy
# 5        DIMAJUMDER@DELOITTE.COM                   Diya Majumder
# 6          DRMITTAL@DELOITTE.COM                  Drishti Mittal
# 7      KJAHNAVIDEVI@DELOITTE.COM             Jahnavi Devi Korada
# 8         KNAUTIYAL@DELOITTE.COM               Kushagra Nautiyal
# 9         MAHKUMARI@DELOITTE.COM                     Mahi Kumari
# 10            MOKDD@DELOITTE.COM                   Mokshitha D D
# 11        NANDINLNU@DELOITTE.COM                       Nandini
# 12      NEHASHARMA3@DELOITTE.COM                     Neha Sharma
# ...

# %%
df.describe()
# Out:
#        2023-04-10 00:00:00  2023-04-11 00:00:00  2023-04-12 00:00:00  \
# count            47.000000            47.000000            47.000000
# mean              0.936170             0.936170             0.957447
# std               0.247092             0.247092             0.204030
# min               0.000000             0.000000             0.000000
# 25%               1.000000             1.000000             1.000000
# 50%               1.000000             1.000000             1.000000
# 75%               1.000000             1.000000             1.000000
# max               1.000000             1.000000             1.000000
#
#        2023-04-13 00:00:00  2023-04-14 00:00:00  MCQ Test (30)  \
# count            47.000000            47.000000      47.000000
# mean              0.957447             0.957447      24.255319
# std               0.204030             0.204030       5.620104
# min               0.000000             0.000000       0.000000
# ...

# %%
df['Percentage']=df['MCQ Test (30)']*100/30
df
# Out:
#                Deloitte Email ID                       Full Name  \
# 0       AARCAGRAWAL@DELOITTE.COM                  Aarchi Agrawal
# 1          AKKAKANI@DELOITTE.COM                   Akshit Kakani
# 2       ANASONAWANE@DELOITTE.COM                 Anagha Sonawane
# 3         CHITIWARI@DELOITTE.COM              Chiranjeev  Tiwari
# 4            DMONCY@DELOITTE.COM                      Dawn Moncy
# 5        DIMAJUMDER@DELOITTE.COM                   Diya Majumder
# 6          DRMITTAL@DELOITTE.COM                  Drishti Mittal
# 7      KJAHNAVIDEVI@DELOITTE.COM             Jahnavi Devi Korada
# 8         KNAUTIYAL@DELOITTE.COM               Kushagra Nautiyal
# 9         MAHKUMARI@DELOITTE.COM                     Mahi Kumari
# 10            MOKDD@DELOITTE.COM                   Mokshitha D D
# 11        NANDINLNU@DELOITTE.COM                       Nandini
# 12      NEHASHARMA3@DELOITTE.COM                     Neha Sharma
# ...

# %%
df.to_csv('test_data.csv')

# %%
# JSON Files

# %%
df=pd.read_json('mydata.json')

# %%
df
# Out:
#        Name       City      Dept
# 1   Prateek      Delhi       DTA
# 2  Sarfaraz  Hyderabad       Tax
# 3      Neha  Bangalore  Advisory
# 4      Mahi     Mumbai       Tax

# %%
# Reading from HTML Files

# %%
with open('table.txt') as file:
    html_code=file.read()
    df=pd.read_html(html_code)
    df

# %%
df[0]
# Out:
#    S.No.                  Book Title           Author
# 0    1.0  Java 2: Complete Reference  Herbert Schildt
# 1    2.0       Programming in Python      James Liang

# %%
data=pd.read_html('https://www.w3schools.com/html/html_tables.asp')
data
# Out:
# [                        Company           Contact  Country
#  0           Alfreds Futterkiste      Maria Anders  Germany
#  1    Centro comercial Moctezuma   Francisco Chang   Mexico
#  2                  Ernst Handel     Roland Mendel  Austria
#  3                Island Trading     Helen Bennett       UK
#  4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
#  5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy,
#            Tag                                        Description
#  0     <table>                                    Defines a table
#  1        <th>                   Defines a header cell in a table
#  2        <tr>                           Defines a row in a table
#  3        <td>                          Defines a cell in a table
#  4   <caption>                            Defines a table caption
#  5  <colgroup>  Specifies a group of one or more columns in a ...
#  6       <col>  Specifies column properties for each column wi...
# ...

# %%
data[0]
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy

# %%
data[1]
# Out:
#           Tag                                        Description
# 0     <table>                                    Defines a table
# 1        <th>                   Defines a header cell in a table
# 2        <tr>                           Defines a row in a table
# 3        <td>                          Defines a cell in a table
# 4   <caption>                            Defines a table caption
# 5  <colgroup>  Specifies a group of one or more columns in a ...
# 6       <col>  Specifies column properties for each column wi...
# 7     <thead>               Groups the header content in a table
# 8     <tbody>                 Groups the body content in a table
# 9     <tfoot>               Groups the footer content in a table

# %%
data=pd.read_html('http://agmarknet.gov.in/SearchCmmMkt.aspx?Tx_Commodity=17&Tx_State=HP&Tx_District=6&Tx_Market=0&DateFrom=20-Mar-2023&DateTo=20-Apr-2023&Fr_Date=20-Mar-2023&To_Date=20-Apr-2023&Tx_Trend=0&Tx_CommodityHead=Apple&Tx_StateHead=Himachal+Pradesh&Tx_DistrictHead=Chamba&Tx_MarketHead=--Select--')

# %%
data[0]
# Out:
#     Sl no. District Name Market Name Commodity          Variety   Grade  \
# 0        1        Chamba      Chamba     Apple  Royal Delicious  Medium
# 1        2        Chamba      Chamba     Apple  Royal Delicious  Medium
# 2        3        Chamba      Chamba     Apple  Royal Delicious  Medium
# 3        4        Chamba      Chamba     Apple  Royal Delicious  Medium
# 4        5        Chamba      Chamba     Apple  Royal Delicious  Medium
# 5        6        Chamba      Chamba     Apple  Royal Delicious  Medium
# 6        7        Chamba      Chamba     Apple  Royal Delicious  Medium
# 7        8        Chamba      Chamba     Apple  Royal Delicious  Medium
# 8        9        Chamba      Chamba     Apple  Royal Delicious  Medium
# 9       10        Chamba      Chamba     Apple  Royal Delicious  Medium
# 10      11        Chamba      Chamba     Apple  Royal Delicious  Medium
# 11      12        Chamba      Chamba     Apple  Royal Delicious  Medium
#
# ...

# %% [markdown]
# ## API Calls

# %%
import requests

# %%
# GET/POST

# %%
response=requests.get('https://catfact.ninja/fact')

# %%
response
# Out:
# <Response [200]>

# %%
# 200- OK, 400+ - Resource at URL is not found
# 500+ - Server is not available
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"fact":"Approximately 40,000 people are bitten by cats in the U.S. annually.","length":68}'

# %%
response.json()
# Out:
# {'fact': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#  'length': 68}

# %%
response.json()['fact']
# Out:
# 'Approximately 40,000 people are bitten by cats in the U.S. annually.'

# %%
info=response.headers
info['server']
# Out:
# 'nginx'

# %%
if response.status_code==200:
    print(response.json()['fact'])
else:
    print('No Response')
# Out:
# Approximately 40,000 people are bitten by cats in the U.S. annually.

# %%
# https://api.nationalize.io?name=prateek
response=requests.get('https://api.nationalize.io?name=Dawn')
if response.status_code==200:
    d=response.json()
    print(f"Country Code: {d['country'][0]['country_id']}")
    print(f"Probability: {d['country'][0]['probability']}")
else:
    print('No Response')
# Out:
# Country Code: US
# Probability: 0.168

# %%
# https://api.coindesk.com/v1/bpi/currentprice.json
import time
for i in range(6):
    response=requests.get('https://api.coindesk.com/v1/bpi/currentprice.json')
    d=response.json()
    coin=d['chartName']
    price=d['bpi']['USD']['rate']
    print(f'{coin} rate today is $ {price}')
    time.sleep(10)
# Out:
# Bitcoin rate today is $ 28,953.1716
# Bitcoin rate today is $ 28,953.1716
# Bitcoin rate today is $ 28,953.1716
# Bitcoin rate today is $ 28,953.1716
# Bitcoin rate today is $ 28,953.1716
# Bitcoin rate today is $ 28,935.2703

# %%
import requests

# %%
response=requests.get('http://127.0.0.1:5000')
print(response.text)
# Out:
# Welcome to Deloitte API Server.

# %%
response=requests.get('http://127.0.0.1:5000/details')
print(response.json()['msg'])
# Out:
# Office Location: Hydearabad Locality: Hitech City Towers: 03

# %%
response=requests.get('http://127.0.0.1:5000/bitcoin')
print(response.text)
# Out:
# Bitcoin rate today is $ 28,929.0175

# %%
import requests
num=input('Enter a number to find factorial: ')
response=requests.get('http://127.0.0.1:5000/factorial?number='+num)
print(response.text)
# Out:
# Enter a number to find factorial: 8
# Factorial of 8 is: 40320

# %%
## Add an API endpoint that receives the current timestamp from the calling
# module and saves/append it into a text file.

# %%
import datetime
now=datetime.datetime.now()
print(now)
# Out:
# 2023-04-20 15:13:30.518918

# %%
import requests
import datetime
now=datetime.datetime.now()
response=requests.get('http://127.0.0.1:5000/stamp_log?tstamp='+str(now))
print(response.text)
# Out:
# Success

# %%
# requests.post()
# requests.get(URL, auth=('user', 'poass'))

# %%
# SHORT BREAK

# %% [markdown]
# ### Unit Testing using PyTest

# %%
import math
math.sqrt(3.14)
# Out:
# 1.772004514666935

# %%
2*math.pi*10
# Out:
# 62.83185307179586

# %%
math.pi*(5**2)
# Out:
# 78.53981633974483
